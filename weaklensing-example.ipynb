# %%
from calculate_ellipticities import make_ellipticity_bias_plot

# %% [markdown]
# Give filenames for submission and truth catalogues, in the required format for the Challenge:

# %%
sub_cat_path = './data/ANNA_9200MHz_1000h_v1.txt'
truth_cat_path = './data/True_1400_v2.txt'

# %% [markdown]
# Make plots of the linear ellipticity bias and histograms of ellipticity modulus and position angles.
#
# Note here we have set `train=True` as that is the only region included in this submission catalogue.

# %%
make_ellipticity_bias_plot(sub_cat_path, truth_cat_path, 9200, train=True)
# Out:
# 2020-10-14 17:17:25,187 [MainThread  ][INFO ] SKAO Science Data Challenge Scoring Pipeline
# 2020-10-14 17:17:25,188 [MainThread  ][INFO ] Scoring pipeline started
# 2020-10-14 17:17:25,207 [MainThread  ][INFO ] NumExpr defaulting to 4 threads.
# 2020-10-14 17:17:27,234 [MainThread  ][INFO ] Catalogue preparation complete. Elapsed time: 2.05s
# 2020-10-14 17:17:30,729 [MainThread  ][INFO ] Crossmatch runs complete. Elapsed time: 5.54s
# 2020-10-14 17:17:30,765 [MainThread  ][INFO ] Sieving complete. Elapsed time: 5.58s
# 2020-10-14 17:17:30,768 [MainThread  ][INFO ] Scoring pipeline complete. Elapsed time: 5.58s
# 2020-10-14 17:17:30,769 [MainThread  ][INFO ] Final score: 0.00
# /Users/harrison/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# ...
